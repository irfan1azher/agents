# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.9)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.9)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.
#
# Having problems with missing Python versions in that list? Have you ever used Anaconda before? It might be interferring. Quit Cursor, bring up a new command line, and make sure that your Anaconda environment is deactivated:
# `conda deactivate`
# And if you still have any problems with conda and python versions, it's possible that you will need to run this too:
# `conda config --set auto_activate_base false`
# and then from within the Agents directory, you should be able to run `uv python list` and see the Python 3.12 version.

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file should have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')

if deepseek_api_key:
    print(f"OpenAI API Key exists and begins {deepseek_api_key[:8]}")
else:
    print("OpenAI API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenAI API Key exists and begins sk-341a8

# %%
# And now - the all important import statement
# If you get an import error - head over to troubleshooting in the Setup folder
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)

client = OpenAI(api_key=os.environ.get('DEEPSEEK_API_KEY'), base_url="https://api.deepseek.com")

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "What is 2+2?"}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 4.1 nano, the incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = client.chat.completions.create(
    model="deepseek-chat",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# Let’s break it down:
#
# We start with the number **2**.
# If we add **2** more to it, we get:
#
# \[
# 2 + 2 = 4
# \]
#
# So, the answer is **4**.

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 4.1 mini, still cheap but more powerful than nano

response = client.chat.completions.create(
    model="deepseek-chat",
    messages=messages
)

question = response.choices[0].message.content

print(question)
# Out:
# A man looks at a portrait and says, "Brothers and sisters I have none, but this man's father is my father's son." Who is in the portrait?

# %%
# form a new messages list
messages = [{"role": "user", "content": question}]

# %%
# Ask it again

response = client.chat.completions.create(
    model="deepseek-chat",
    messages=messages
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let’s break it down step-by-step.
#
# The man says:
#
# > "Brothers and sisters I have none, but this man's father is my father's son."
#
# ---
#
# **Step 1: Interpret "Brothers and sisters I have none"**
# This means he has no siblings. So he is an only child.
#
# ---
#
# **Step 2: Interpret "this man's father"**
# He is looking at a portrait of someone (call that person in the portrait **P**).
# So "this man" refers to **P**.
# "this man's father" = **P’s father**.
#
# ---
#
# **Step 3: Interpret "my father's son"**
# The speaker’s father has only one child (the speaker himself, because he has no brothers or sisters).
# So "my father's son" = **the speaker himself**.
#
# ---
#
# **Step 4: Put it together**
# The statement says:
# > P’s father = my father’s son
# But "my father’s son" = me (the speaker).
# So:
# P’s father = me.
#
# ---
#
# **Step 5: Conclusion**
# If P’s father is the speaker, then P is the speaker’s **son**.
#
# ---
#
# **Final answer:** The portrait is of his **son**.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# Let’s break it down step-by-step.
#
# The man says:
#
# > "Brothers and sisters I have none, but this man's father is my father's son."
#
# ---
#
# **Step 1: Interpret "Brothers and sisters I have none"**
# This means he has no siblings. So he is an only child.
#
# ---
#
# **Step 2: Interpret "this man's father"**
# He is looking at a portrait of someone (call that person in the portrait **P**).
# So "this man" refers to **P**.
# "this man's father" = **P’s father**.
#
# ---
#
# **Step 3: Interpret "my father's son"**
# The speaker’s father has only one child (the speaker himself, because he has no brothers or sisters).
# So "my father's son" = **the speaker himself**.
#
# ---
#
# **Step 4: Put it together**
# The statement says:
# > P’s father = my father’s son
# But "my father’s son" = me (the speaker).
# So:
# P’s father = me.
#
# ---
#
# **Step 5: Conclusion**
# If P’s father is the speaker, then P is the speaker’s **son**.
#
# ---
#
# **Final answer:** The portrait is of his **son**.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "list out area of opportunities in Riyadh,KSA in agentic AI space"}]

# Then make the first call:

response = client.chat.completions.create(
    model="deepseek-chat",
    messages=messages
)

# Then read the business idea:

business_idea = response.choices[0].message.content

print(business_idea)

# And repeat! In the next message, include the business idea within the message
# Out:
# Of course. Riyadh, as the capital and financial hub of Saudi Arabia, is at the epicenter of the Kingdom's transformative Vision 2030. This creates a uniquely fertile ground for Agentic AI—where AI doesn't just recommend actions but *plans and executes* complex, multi-step tasks autonomously.
#
# Here is a detailed list of area of opportunities in the Agentic AI space in Riyadh, categorized by sector and strategic theme.
#
# ---
#
# ### 1. Public Sector & Smart Government
# The Saudi government is a massive, centralized entity with a clear mandate for digital transformation. Agentic AI can be the engine for this.
#
# *   **Citizen Service Agents:** Autonomous agents that handle complex, multi-departmental citizen requests. Instead of a chatbot giving information, an agent could *execute* the entire process of, for example, starting a business: reserving a trade name, filling out MOQ forms, applying for a commercial license, and scheduling notary appointments—all with minimal human input.
# *   **Regulatory Compliance & Licensing Agents:** Agents that continuously monitor business activities, auto-fill compliance reports, and proactively apply for license renewals by pulling data from various government systems (e.g., MISA, GAZT, MoH).
# *   **Intelligent Urban Management Agents:** Systems that autonomously manage city infrastructure. For example, an agent that optimizes traffic light timing in real-time across Riyadh based on live traffic, event data, and public transport schedules, or one that manages water and electricity grid distribution dynamically.
#
# ### 2. Finance & Banking
# Riyadh is the financial capital of the GCC. The sector is ripe for automation beyond simple chatbots.
#
# *   **Personalized Wealth Management Agents:** AI agents that act as robo-advisors on steroids. They wouldn't just suggest a portfolio; they would autonomously rebalance it, execute trades, monitor global market news for risks/opportunities, and even handle tax-loss harvesting specific to Saudi tax law.
# *   **Corporate Onboarding & KYC Agents:** For banks, an agent that autonomously guides a corporate client through the entire onboarding process: collecting documents, running AML/KYC checks against local and international databases, performing risk assessments, and setting up accounts and credit facilities.
# *   **Fraud Investigation Swarms:** Instead of a single system flagging fraud, a swarm of specialized agents could work together: one analyzes transaction patterns, another checks device fingerprints, a third monitors for social engineering keywords in call center logs, and a "manager" agent correlates the findings to autonomously block transactions and file suspicious activity reports with SAMA.
#
# ### 3. Giga-Projects & Real Estate
# Riyadh is the headquarters for many giga-projects (e.g., Diriyah Gate, Qiddiya, ROSHN). The scale and complexity are perfect for Agentic AI.
#
# *   **Project Management Agents:** An agent that acts as a virtual project manager for a specific tower or district. It ingests data from BIM models, supplier databases, and weather feeds to autonomously reschedule tasks due to delays, reorder materials based on consumption rates, and flag potential budget overruns to human managers.
# *   **Smart Building & Community Management:** For completed developments like ROSHN, agents can manage community-wide systems. They could autonomously optimize energy use across hundreds of villas, manage booking and maintenance for shared amenities (pools, gyms), and coordinate drone-based security patrols.
# *   **Automated Tenant Lifecycle Agents:** Handle the entire tenant journey: from finding a property and conducting virtual tours, to autonomously processing rental applications, generating and e-signing contracts via Absher, managing move-in/move-out inspections, and handling maintenance requests by dispatching the correct vendor.
#
# ### 4. Healthcare
# The healthcare sector is undergoing massive investment and faces challenges of scale and efficiency.
#
# *   **Personalized Patient Journey Agents:** An agent assigned to a chronic disease patient (e.g., diabetes) that coordinates their care. It schedules appointments, refills prescriptions by interfacing with pharmacies, reminds the patient to take medication and log vitals, and alerts a human doctor only if readings exceed a threshold.
# *   **Hospital Operational Agents:** Agents that manage complex hospital logistics. For instance, an agent that autonomously manages the inventory of critical supplies, predicts shortages, and places orders with pre-approved vendors. Another could optimize surgery scheduling by considering surgeon availability, equipment sterilization cycles, and bed occupancy in recovery.
# *   **Diagnostic Support Swarms:** A team of agents that analyze a patient's file: one reads MRI scans, another analyzes lab results, a third reviews the patient's history from different providers. They combine their findings to present a unified, prioritized differential diagnosis to the physician.
#
# ### 5. Logistics & Supply Chain
# As a central logistics hub, Riyadh's efficiency is critical to the Kingdom.
#
# *   **Autonomous Supply Chain Orchestrators:** An agent that doesn't just track a shipment but *manages* it. If a delay occurs at the port of Jeddah, the agent autonomously re-routes the shipment via land, re-calculates ETAs, updates all stakeholders, and manages the financial penalties/contracts with the shipping company.
# *   **Last-Mile Delivery Optimization Agents:** For companies like Jahez and HungerStation, an agent that dynamically manages a fleet of drivers in real-time. It doesn't just assign an order; it continuously re-optimizes routes based on live traffic (a major issue in Riyadh), new orders, and driver performance, acting as an autonomous dispatch manager.
#
# ### 6. Cross-Cutting & Foundational Opportunities
#
# *   **Arabic-Language Native Agentic Systems:** Developing the core AI models and platforms specifically designed to understand the nuances of Saudi dialect, culture, and business etiquette. This is a massive moat.
# *   **Agentic AI for Cybersecurity:** Autonomous security agents that don't just alert but actively defend a network. They could isolate compromised devices, deploy patches, and hunt for threats across an organization's entire digital footprint in Riyadh.
# *   **Consulting & Integration Services:** A huge opportunity for firms that can help large Saudi enterprises and government bodies *design* and *implement* agentic workflows, integrating them with legacy systems like SAP and Oracle.
#
# ---
#
# ### Key Success Factors & Challenges in the Riyadh Context:
#
# *   **Data Access & Silos:** Gaining access to the high-quality, structured data needed to fuel these agents, especially across different government entities.
# *   **Regulatory Sandbox:** Working with regulators like SDAIA, CITC, and NDMO to create a safe environment for testing and deploying autonomous systems.
# *   **Cultural Acceptance:** Building trust in systems that make autonomous decisions, which requires transparency and robust oversight mechanisms.
# *   **Talent:** The war for AI talent is global. Attracting and training top researchers and engineers will be crucial.
#
# **Conclusion:** Riyadh is not just another market for Agentic AI; it is a blueprint for the future. The combination of strong central vision, immense financial resources, and a pressing need for efficiency creates an unparalleled opportunity to build and deploy the next generation of autonomous AI systems that will redefine how a modern city and nation operate.
